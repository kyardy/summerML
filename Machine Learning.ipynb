# %%
import numpy as np
from sklearn import preprocessing, cross_validation,neighbors,svm
import pandas as pd

df = pd.read_csv('testData.csv')

df.replace ('-', -99999, inplace=True) # replacing anything with a -

#df.drop(['GPS Time'],1,inplace=True)

#feature_col_names=['GPS_Speed','Absolute_Throttle_Position_B','Average_trip_speed(moving only)','Engine_Load(%)','Engine_Load(Absolute)(%)','Engine_RPM','Fuel flow rate/hour(gal/hr)','Fuel flow rate/minute(gal/min)','Relative Throttle Position(%)','Speed(mph)','Throttle Position(Manifold)(%)','Torque(Nm)']
#predicted_class_names = ['Normal Driving]


X = np.array(df.drop(['Normal Driving'],1))
y = np.array(df['Normal Driving']) #features 

X_train, X_test, y_train, y_test = cross_validation.train_test_split(X,y,test_size=0.2) #Shuffling data into testing and training chunks
clf = svm.SVC()
clf.fit(X_train, y_train)


accuracy = clf.score(X_test, y_test)
print(accuracy)
#raw_data = open(filename,'rt')
#data = numpy.loadtxt(raw_data,delimiter=",")
#print(data.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-062dd7cf2e91> in <module>()
#      18 X_train, X_test, y_train, y_test = cross_validation.train_test_split(X,y,test_size=0.2) #Shuffling data into testing and training chunks
#      19 clf = svm.SVC()
# ---> 20 clf.fit(X_train, y_train)
#      21
#      22
#
# C:\Users\Public\Anaconda\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     148
#     149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
# --> 150         y = self._validate_targets(y)
#     151
#     152         sample_weight = np.asarray([]
#
# C:\Users\Public\Anaconda\lib\site-packages\sklearn\svm\base.py in _validate_targets(self, y)
#     504             raise ValueError(
#     505                 "The number of classes has to be greater than one; got %d"
# --> 506                 % len(cls))
#     507
#     508         self.classes_ = cls
#
# ValueError: The number of classes has to be greater than one; got 1

# %%
import pandas as pd          #Pandas is a dataframe library
import matplotlib.pyplot as plt      #Library plots data
import numpy as np                  #numpy provides N-dim object support

df = pd.read_csv('testData.csv')
df.shape

df.head(5)
# Out:
#    GPS_Speed  Absolute_Throttle_Position_B  Average_trip_speed(moving only)  \
# 0   0.036942                      4.313725                          2.30795
# 1   0.257695                      3.921569                          2.30795
# 2   0.034196                      3.921569                          2.30795
# 3   0.011821                      3.529412                          2.30795
# 4   0.011825                      3.529412                          2.30795
#
#    Engine_Load(%)  Engine_Load(Absolute)(%)  Engine_RPM  \
# 0       30.196079                 25.098040       725.0
# 1       28.627451                 21.176470       700.0
# 2       28.235294                 20.392157       687.5
# 3       28.235294                 19.607843       675.0
# 4       29.019608                 20.392157       662.5
#
#    Fuel flow rate/hour(gal/hr)  Fuel flow rate/minute(gal/min)  \
# 0                     0.366512                        0.006109
# 1                     0.336215                        0.005604
# 2                     0.332706                        0.005545
# 3                     0.319000                        0.005317
# 4                     0.330532                        0.005509
#
#    Relative Throttle Position(%)  Speed(mph)  Throttle Position(Manifold)(%)  \
# 0                       1.176471         0.0                        4.313725
# 1                       1.176471         0.0                        3.921569
# 2                       1.176471         0.0                        3.921569
# 3                       1.176471         0.0                        3.921569
# 4                       1.176471         0.0                        3.921569
#
#   Torque(Nm)  Normal Driving
# 0          -               1
# 1          -               1
# 2          -               1
# 3          -               1
# 4          -               1
